# %% [markdown]
# <a href="https://colab.research.google.com/github/ulya1202/Computer_vision_projects/blob/main/ResNET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##34 layer

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import tensorflow as tf

# %%
inputs=tf.keras.layers.Input(shape=(32,32,3))
conv1=tf.keras.layers.Conv2D(kernel_size=(7,7), filters=64, strides=(2,2), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
maxpool0=tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides=2)(conv1)
#conv2_x


conv2_0=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, activation='relu', kernel_initializer='he_normal', padding='same' )(maxpool0)
conv2_1=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, activation='relu', kernel_initializer='he_normal', padding='same' )(conv2_0)
add_0=tf.keras.layers.Add()([maxpool0, conv2_1])

conv2_2=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, activation='relu', kernel_initializer='he_normal', padding='same' )(add_0)
conv2_3=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, activation='relu', kernel_initializer='he_normal', padding='same' )(conv2_2)
add_1=tf.keras.layers.Add()([add_0, conv2_3])

conv2_4=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, activation='relu', kernel_initializer='he_normal', padding='same' )(add_1)
conv2_5=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, activation='relu', kernel_initializer='he_normal', padding='same' )(conv2_4)
add_2=tf.keras.layers.Add()([add_1, conv2_5])


#conv3_x
add_2_adjusted=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(add_2)
conv3_0=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(add_2_adjusted)
conv3_1=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(conv3_0)
add_3=tf.keras.layers.Add()([add_2_adjusted, conv3_1])

conv3_2=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(add_3)
conv3_3=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(conv3_2)
add_4=tf.keras.layers.Add()([add_3, conv3_3])

conv3_4=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(add_4)
conv3_5=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(conv3_4)
add_5=tf.keras.layers.Add()([add_4, conv3_5])

conv3_6=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(add_5)
conv3_7=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(conv3_6)
add_6=tf.keras.layers.Add()([add_5, conv3_7])

#conv4_x
add_6_adjusted=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(add_6)
conv4_0=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(add_6_adjusted)
conv4_1=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(conv4_0)
add_7=tf.keras.layers.Add()([add_6_adjusted, conv4_1])

conv4_2=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(add_7)
conv4_3=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(conv4_2)
add_8=tf.keras.layers.Add()([add_7, conv4_3])

conv4_4=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(add_8)
conv4_5=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(conv4_4)
add_9=tf.keras.layers.Add()([add_8, conv4_5])

conv4_6=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(add_9)
conv4_7=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(conv4_6)
add_10=tf.keras.layers.Add()([add_9, conv4_7])

conv4_8=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(add_10)
conv4_9=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(conv4_8)
add_11=tf.keras.layers.Add()([add_10, conv4_9])

conv4_10=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(add_11)
conv4_11=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(conv4_10)
add_12=tf.keras.layers.Add()([add_11, conv4_11])

#conv5_x
add_12_adjusted=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(add_12)
conv5_0=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(add_12_adjusted)
conv5_1=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(conv5_0)
add_13=tf.keras.layers.Add()([add_12_adjusted, conv5_1])

conv5_2=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(add_13)
conv5_3=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(conv5_2)
add_14=tf.keras.layers.Add()([add_13, conv5_3])

conv5_4=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(add_14)
conv5_5=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')(conv5_4)
add_15=tf.keras.layers.Add()([add_14, conv5_5])

#average
average_pool=tf.keras.layers.AveragePooling2D(pool_size=(2,2))(add_15)
flatten = tf.keras.layers.Flatten()(average_pool)
outputs=tf.keras.layers.Dense(10, activation='softmax')(flatten)

# %%
model = tf.keras.Model(inputs=inputs, outputs=outputs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-59600d54b7b8> in <cell line: 0>()
# ----> 1 model = tf.keras.Model(inputs=inputs, outputs=outputs)
#
# NameError: name 'inputs' is not defined

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(5e-4), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
data=tf.keras.datasets.cifar10.load_data()
(X_train_full, y_train_full), (X_test, y_test) = data
X_train, y_train= X_train_full[:45_000],y_train_full[:45_000]
X_val, y_val=X_train_full[45_000:],y_train_full[45_000:]
X_train, X_test, X_val= X_train/255., X_test/255., X_val/255.
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
model.fit(X_train, y_train, epochs=10, validation_data=(X_val, y_val))
# Out:
# Epoch 1/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 49s 23ms/step - accuracy: 0.3139 - loss: 30.4869 - val_accuracy: 0.4778 - val_loss: 1.4338
# Epoch 2/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.4963 - loss: 1.4083 - val_accuracy: 0.5032 - val_loss: 1.3564
# Epoch 3/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 40s 18ms/step - accuracy: 0.5554 - loss: 1.2459 - val_accuracy: 0.5752 - val_loss: 1.1977
# Epoch 4/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - accuracy: 0.6007 - loss: 1.1166 - val_accuracy: 0.6334 - val_loss: 1.0586
# Epoch 5/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - accuracy: 0.6353 - loss: 1.0351 - val_accuracy: 0.6000 - val_loss: 1.1212
# Epoch 6/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - accuracy: 0.6600 - loss: 0.9670 - val_accuracy: 0.6406 - val_loss: 1.0148
# Epoch 7/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - accuracy: 0.6818 - loss: 0.9070 - val_accuracy: 0.6824 - val_loss: 0.9177
# Epoch 8/10
# ...

# %% [markdown]
# ##54 layers

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
inputs=tf.keras.layers.Input(shape=(32,32,3))
conv1=tf.keras.layers.Conv2D(kernel_size=(7,7), filters=64, strides=(2,2), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
maxpool0=tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides=2)(conv1)
maxpool0_adjusted = tf.keras.layers.Conv2D(kernel_size=(1, 1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same')(maxpool0)
#conv2_x
conv2_0=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=64, activation='relu', kernel_initializer='he_normal', padding='same' )(maxpool0_adjusted)
conv2_1=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, activation='relu', kernel_initializer='he_normal', padding='same' )(conv2_0)
conv2_2=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv2_1)
add_0=tf.keras.layers.Add()([maxpool0_adjusted, conv2_2])

conv2_3=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=64, activation='relu', kernel_initializer='he_normal', padding='same' )(add_0)
conv2_4=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, activation='relu', kernel_initializer='he_normal', padding='same' )(conv2_3)
conv2_5=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv2_4)
add_1=tf.keras.layers.Add()([add_0, conv2_5])

conv2_6=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=64, activation='relu', kernel_initializer='he_normal', padding='same' )(add_1)
conv2_7=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, activation='relu', kernel_initializer='he_normal', padding='same' )(conv2_6)
conv2_8=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv2_7)
add_2=tf.keras.layers.Add()([add_1, conv2_8])

#conv3_x
add_2_adjusted=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=512, activation='relu', kernel_initializer='he_normal', padding='same')(add_2)
conv3_0=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=128, activation='relu', kernel_initializer='he_normal', padding='same' )(add_2_adjusted)
conv3_1=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same' )(conv3_0)
conv3_2=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(conv3_1)
add_3=tf.keras.layers.Add()([add_2_adjusted, conv3_2])

conv3_3=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=128, activation='relu', kernel_initializer='he_normal', padding='same' )(add_3)
conv3_4=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same' )(conv3_3)
conv3_5=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(conv3_4)
add_4=tf.keras.layers.Add()([add_3, conv3_5])

conv3_6=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=128, activation='relu', kernel_initializer='he_normal', padding='same' )(add_4)
conv3_7=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same' )(conv3_6)
conv3_8=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(conv3_7)
add_5=tf.keras.layers.Add()([add_4, conv3_8])

conv3_9=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=128, activation='relu', kernel_initializer='he_normal', padding='same' )(add_5)
conv3_10=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same' )(conv3_9)
conv3_11=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(conv3_10)
add_6=tf.keras.layers.Add()([add_5, conv3_11])

#conv4_x
add_6_adjusted=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same')(add_6)
conv4_0=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=156, activation='relu', kernel_initializer='he_normal', padding='same' )(add_6_adjusted)
conv4_1=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_0)
conv4_2=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_1)
add_7=tf.keras.layers.Add()([add_6_adjusted, conv4_2])

conv4_3=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_7)
conv4_4=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_3)
conv4_5=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_4)
add_8=tf.keras.layers.Add()([add_7, conv4_5])

conv4_6=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_8)
conv4_7=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_6)
conv4_8=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_7)
add_9=tf.keras.layers.Add()([add_8, conv4_8])

conv4_9=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_9)
conv4_10=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_9)
conv4_11=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_10)
add_10=tf.keras.layers.Add()([add_9, conv4_11])

conv4_12=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_10)
conv4_13=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_12)
conv4_14=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_13)
add_11=tf.keras.layers.Add()([add_10, conv4_14])

conv4_15=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_11)
conv4_16=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_15)
conv4_17=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_16)
add_12=tf.keras.layers.Add()([add_11, conv4_17])

#conv5_x
add_12_adjusted=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=2048, activation='relu', kernel_initializer='he_normal', padding='same')(add_12)
conv5_0=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(add_12_adjusted)
conv5_1=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(conv5_0)
conv5_2=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=2048, activation='relu', kernel_initializer='he_normal', padding='same' )(conv5_1)
add_13=tf.keras.layers.Add()([add_12_adjusted, conv5_2])

conv5_3=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(add_13)
conv5_4=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(conv5_3)
conv5_5=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=2048, activation='relu', kernel_initializer='he_normal', padding='same' )(conv5_4)
add_14=tf.keras.layers.Add()([add_13, conv5_5])

conv5_6=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(add_14)
conv5_7=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(conv5_6)
conv5_8=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=2048, activation='relu', kernel_initializer='he_normal', padding='same' )(conv5_7)
add_15=tf.keras.layers.Add()([add_14, conv5_8])

#average
average_pool=tf.keras.layers.AveragePooling2D(pool_size=(2,2))(add_15)
flatten = tf.keras.layers.Flatten()(average_pool)
outputs=tf.keras.layers.Dense(10, activation='softmax')(flatten)

# %%
model = tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(5e-4), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=10, validation_data=(X_val, y_val))
# Out:
# Epoch 1/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 180s 103ms/step - accuracy: 0.2625 - loss: 89.4684 - val_accuracy: 0.4660 - val_loss: 1.4681
# Epoch 2/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 176s 95ms/step - accuracy: 0.4808 - loss: 1.4317 - val_accuracy: 0.5206 - val_loss: 1.3253
# Epoch 3/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.5443 - loss: 1.2759 - val_accuracy: 0.5622 - val_loss: 1.2024
# Epoch 4/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 133s 95ms/step - accuracy: 0.5917 - loss: 1.1535 - val_accuracy: 0.5762 - val_loss: 1.1890
# Epoch 5/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.6182 - loss: 1.0803 - val_accuracy: 0.6178 - val_loss: 1.0895
# Epoch 6/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 141s 94ms/step - accuracy: 0.6471 - loss: 0.9943 - val_accuracy: 0.6306 - val_loss: 1.0609
# Epoch 7/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 133s 94ms/step - accuracy: 0.6734 - loss: 0.9307 - val_accuracy: 0.6622 - val_loss: 0.9573
# Epoch 8/10
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 101 layer

# %%
inputs=tf.keras.layers.Input(shape=(32,32,3))
conv1=tf.keras.layers.Conv2D(kernel_size=(7,7), filters=64, strides=(2,2), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
maxpool0=tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides=2)(conv1)
maxpool0_adjusted = tf.keras.layers.Conv2D(kernel_size=(1, 1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same')(maxpool0)
#conv2_x
conv2_0=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=64, activation='relu', kernel_initializer='he_normal', padding='same' )(maxpool0_adjusted)
conv2_1=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, activation='relu', kernel_initializer='he_normal', padding='same' )(conv2_0)
conv2_2=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv2_1)
add_0=tf.keras.layers.Add()([maxpool0_adjusted, conv2_2])

conv2_3=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=64, activation='relu', kernel_initializer='he_normal', padding='same' )(add_0)
conv2_4=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, activation='relu', kernel_initializer='he_normal', padding='same' )(conv2_3)
conv2_5=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv2_4)
add_1=tf.keras.layers.Add()([add_0, conv2_5])

conv2_6=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=64, activation='relu', kernel_initializer='he_normal', padding='same' )(add_1)
conv2_7=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, activation='relu', kernel_initializer='he_normal', padding='same' )(conv2_6)
conv2_8=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv2_7)
add_2=tf.keras.layers.Add()([add_1, conv2_8])

#conv3_x
add_2_adjusted=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=512, activation='relu', kernel_initializer='he_normal', padding='same')(add_2)
conv3_0=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=128, activation='relu', kernel_initializer='he_normal', padding='same' )(add_2_adjusted)
conv3_1=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same' )(conv3_0)
conv3_2=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(conv3_1)
add_3=tf.keras.layers.Add()([add_2_adjusted, conv3_2])

conv3_3=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=128, activation='relu', kernel_initializer='he_normal', padding='same' )(add_3)
conv3_4=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same' )(conv3_3)
conv3_5=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(conv3_4)
add_4=tf.keras.layers.Add()([add_3, conv3_5])

conv3_6=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=128, activation='relu', kernel_initializer='he_normal', padding='same' )(add_4)
conv3_7=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same' )(conv3_6)
conv3_8=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(conv3_7)
add_5=tf.keras.layers.Add()([add_4, conv3_8])

conv3_9=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=128, activation='relu', kernel_initializer='he_normal', padding='same' )(add_5)
conv3_10=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, activation='relu', kernel_initializer='he_normal', padding='same' )(conv3_9)
conv3_11=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(conv3_10)
add_6=tf.keras.layers.Add()([add_5, conv3_11])

#conv4_x
add_6_adjusted=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same')(add_6)
conv4_0=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=156, activation='relu', kernel_initializer='he_normal', padding='same' )(add_6_adjusted)
conv4_1=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_0)
conv4_2=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_1)
add_7=tf.keras.layers.Add()([add_6_adjusted, conv4_2])

conv4_3=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_7)
conv4_4=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_3)
conv4_5=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_4)
add_8=tf.keras.layers.Add()([add_7, conv4_5])

conv4_6=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_8)
conv4_7=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_6)
conv4_8=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_7)
add_9=tf.keras.layers.Add()([add_8, conv4_8])

conv4_9=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_9)
conv4_10=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_9)
conv4_11=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_10)
add_10=tf.keras.layers.Add()([add_9, conv4_11])

conv4_12=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_10)
conv4_13=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_12)
conv4_14=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_13)
add_11=tf.keras.layers.Add()([add_10, conv4_14])

conv4_15=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_11)
conv4_16=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_15)
conv4_17=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_16)
add_12=tf.keras.layers.Add()([add_11, conv4_17])

conv4_18=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=156, activation='relu', kernel_initializer='he_normal', padding='same' )(add_12)
conv4_19=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_18)
conv4_20=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_19)
add_13=tf.keras.layers.Add()([add_12, conv4_20])

conv4_21=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_13)
conv4_22=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_21)
conv4_23=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_22)
add_14=tf.keras.layers.Add()([add_13, conv4_23])

conv4_24=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_14)
conv4_25=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_24)
conv4_26=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_25)
add_15=tf.keras.layers.Add()([add_14, conv4_26])

conv4_27=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_15)
conv4_28=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_27)
conv4_29=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_28)
add_16=tf.keras.layers.Add()([add_15, conv4_29])

conv4_30=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_16)
conv4_31=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_30)
conv4_32=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_31)
add_17=tf.keras.layers.Add()([add_16, conv4_32])

conv4_33=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_17)
conv4_34=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_33)
conv4_35=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_34)
add_18=tf.keras.layers.Add()([add_17, conv4_35])

conv4_36=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=156, activation='relu', kernel_initializer='he_normal', padding='same' )(add_18)
conv4_37=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_36)
conv4_38=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_37)
add_19=tf.keras.layers.Add()([add_18, conv4_38])

conv4_39=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_19)
conv4_40=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_39)
conv4_41=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_40)
add_20=tf.keras.layers.Add()([add_19, conv4_41])

conv4_42=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_20)
conv4_43=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_42)
conv4_44=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_43)
add_21=tf.keras.layers.Add()([add_20, conv4_44])

conv4_45=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_21)
conv4_46=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_45)
conv4_47=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_46)
add_22=tf.keras.layers.Add()([add_21, conv4_47])

conv4_48=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_22)
conv4_49=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_48)
conv4_50=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_49)
add_23=tf.keras.layers.Add()([add_22, conv4_50])

conv4_51=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_23)
conv4_52=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_51)
conv4_53=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_52)
add_24=tf.keras.layers.Add()([add_11, conv4_53])

conv4_54=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=156, activation='relu', kernel_initializer='he_normal', padding='same' )(add_24)
conv4_55=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_54)
conv4_56=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_55)
add_25=tf.keras.layers.Add()([add_24, conv4_56])

conv4_57=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_25)
conv4_58=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_57)
conv4_59=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_58)
add_26=tf.keras.layers.Add()([add_25, conv4_59])

conv4_60=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_26)
conv4_61=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_60)
conv4_62=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_61)
add_27=tf.keras.layers.Add()([add_26, conv4_62])

conv4_63=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_27)
conv4_64=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_63)
conv4_65=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_64)
add_28=tf.keras.layers.Add()([add_27, conv4_65])

conv4_66=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(add_28)
conv4_67=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_66)
conv4_68=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=1024, activation='relu', kernel_initializer='he_normal', padding='same' )(conv4_67)
add_29=tf.keras.layers.Add()([add_28, conv4_68])


#conv5_x
add_29_adjusted=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=2048, activation='relu', kernel_initializer='he_normal', padding='same')(add_29)
conv5_0=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(add_29_adjusted)
conv5_1=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(conv5_0)
conv5_2=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=2048, activation='relu', kernel_initializer='he_normal', padding='same' )(conv5_1)
add_30=tf.keras.layers.Add()([add_29_adjusted, conv5_2])

conv5_3=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(add_30)
conv5_4=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(conv5_3)
conv5_5=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=2048, activation='relu', kernel_initializer='he_normal', padding='same' )(conv5_4)
add_31=tf.keras.layers.Add()([add_30, conv5_5])

conv5_6=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(add_31)
conv5_7=tf.keras.layers.Conv2D(kernel_size=(3,3), filters=512, activation='relu', kernel_initializer='he_normal', padding='same' )(conv5_6)
conv5_8=tf.keras.layers.Conv2D(kernel_size=(1,1), filters=2048, activation='relu', kernel_initializer='he_normal', padding='same' )(conv5_7)
add_32=tf.keras.layers.Add()([add_31, conv5_8])

#average
average_pool=tf.keras.layers.AveragePooling2D(pool_size=(2,2))(add_15)
flatten = tf.keras.layers.Flatten()(average_pool)
outputs=tf.keras.layers.Dense(10, activation='softmax')(flatten)

# %%
model = tf.keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=tf.keras.optimizers.Adam(5e-4), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=10, validation_data=(X_val, y_val))
# Out:
# Epoch 1/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 103s 58ms/step - accuracy: 0.2495 - loss: 64.5624 - val_accuracy: 0.4596 - val_loss: 1.4852
# Epoch 2/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 73s 52ms/step - accuracy: 0.4690 - loss: 1.4672 - val_accuracy: 0.5156 - val_loss: 1.3610
# Epoch 3/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 83s 52ms/step - accuracy: 0.5330 - loss: 1.3093 - val_accuracy: 0.5656 - val_loss: 1.2323
# Epoch 4/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 80s 51ms/step - accuracy: 0.5856 - loss: 1.1811 - val_accuracy: 0.6080 - val_loss: 1.1013
# Epoch 5/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 71s 51ms/step - accuracy: 0.6175 - loss: 1.0833 - val_accuracy: 0.6254 - val_loss: 1.0540
# Epoch 6/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 85s 53ms/step - accuracy: 0.6497 - loss: 0.9969 - val_accuracy: 0.6648 - val_loss: 0.9620
# Epoch 7/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 80s 51ms/step - accuracy: 0.6828 - loss: 0.9038 - val_accuracy: 0.6650 - val_loss: 0.9760
# Epoch 8/10
# ...

# %%
# from functools import partial
# import numpy as np
# c4=np.zeros(24)
# for i in range(0,24,)
# DefaultConv2D__1=partial(kernel_size=(1,1), filters=128, activation='relu', kernel_initializer='he_normal', padding='same')
